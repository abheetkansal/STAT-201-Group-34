# %% [markdown]
# # STAT 201: Group 34 Project

# %% [markdown]
# Abheet Kansal, Sebastian Csizmazia, Kaitlin Khu, Lim Pei Chan

# %% [markdown]
# ## Surveying Crime Data in Vancouver

# %% [markdown]
# **INTRODUCTION:**
# Background Information:
# Vancouver’s crime rates have drastically increased recently, with a crime index of 39.18% (Numbeo, 2022), where crime levels of 40%-60% are considered moderate. This surge is due to the results of the loss of jobs caused by the pandemic (CBC News, 2022), increase in rent (CBC News, 2022), and the increased use of drugs often leading to homelessness, hence forcing many to commit crime in order to survive. It can then be deduced that more disadvantaged areas such as Downtown East Side, and South Vancouver neighborhoods (Webster, N.A.) would experience higher rates of crime. Hence, this results in an increasingly unsafe environment for Vancouver residents and requires increased surveillance by law enforcement in neighborhood areas.
#
# Comparing the neighbourhoods Kitsilano and Kerrisdale, since both are more residential neighbourhoods, it would be assumed to be relatively safer, however, Kitsilano crime rates are 19% higher than the national average (Areavibes, 2020), whereas Kerrisdale’s crime rates are 43% lower than the national average (Areavibes, 2020). This can be deduced due to Kitsilano having increased traffic due to increased commercialization in the introduction of stores and famous beaches, meaning more people aside from those who are residing there, so we can assume that there are higher crime rates.
#
#
# **Rows in the 2022 Crime Dataset**
# *  `TYPE` : Crime Type
# *  `YEAR` : Year crime was reported to occur
# *  `MONTH` : Month crime was reported to occur
# *  `DAY` : Day crime was reported to occur
# *  `HOUR` : Hour of the day crime was reported to occur
# *  `MINUTE` : Minute of the hour crime was reported to occur
# *  `HUNDRED_BLOCK` : Location where crime was taken place
# *  `NEIGHBOURHOOD` : Generalized neighbourhood where the crime took place
# *  `X` : Coordinate values
# *  `Y` : Coordinate values

# %% [markdown]
# **Research Question 1:** </br>
# Let <i>p<sub>1</sub></i> be the proportion of offence against a person among all other types of crime in the Central Business District </br>
# Let <i>p<sub>2</sub></i> be the proportion of offence against a person among all other types of crime in the West End </br>
#
#
# <center><i>H<sub>θ</sub></i> : <i>p<sub>1</sub></i>=<i>p<sub>2</sub></i></center>
# The proportion of offence against person among all other types of crime is the same in Central Business District and West End in Vancouver<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</br>
#
# <center><i>H<sub>1</sub></i> : <i>p<sub>1</sub></i>><i>p<sub>2</sub></i> </center>
#
# The proportion of offence against person among all other types of crime in West End is less than the proportion in Central Business District in Vancouver

# %% [markdown]
# **Dataset Information:**
# The crime data set we will be using is from the <i>Crime Data Download<i/> published by the <i>Vancouver Police Department</i>. Looking specifically at the year 2022, in all the neighborhoods, and focusing on the crime type of: Crime Against a Person.
#
# <table style="width:100%">
#   <tr>
#     <th>Attribute</th>
#     <th>Value</th>
#   </tr>
#   <tr>
#     <td>Crime Type</td>
#     <td>&nbsp;&nbsp;&nbsp;Offence Against Person</td>
#   </tr>
#   <tr>
#     <td>Year</td>
#     <td>&nbsp;&nbsp;&nbsp;2022</td>
#   </tr>
#   <tr>
#       <td>Neighbourhood</td>
#       <td>
#           <ol type="1">
#                <li><b>Central Buisness District</b></li>
#                <li><b>West End</b></li>
#                <li><b>Kitsilano</b></li>
#                <li><b>Kerrisdale</b></li>
#           </ol>
#       </td>
#   </tr>
# </table>
#
#
# We’ve hypothesized that the neighborhood Central Business District and West end as both are located in Downtown Vancouver would have the highest rates of Crime Against a Person due to the nature of the neighborhood.

# %% [markdown]
# <b>METHODS:</b>  We’ll begin by using Hypothesis testing to assess the plausibility of the hypothesis, whether the data obtained from samples provides evidence against our claim that H. Through the infer workflow, which ensures tidy and clean data while using expressive grammar for the statistical inference, we will calculate the p-value. The p-value will be used to reject the null hypothesis H. Then through samples obtained through bootstrap resampling with replacement, which allows us to mimic sampling variation without the full population, we will calculate our point estimate of sample proportion and visualize the results with a confidence interval of 95% to conclude to stakeholders how confident we are with the results.
#
# We expect that the p-value to be smaller than the significance level to reject our null hypothesis. This can prove our point that the Central Business District has higher crime rates than the West End.
#
# The significance of this report and its final results can allow us to determine which areas require higher levels of law enforcement and increased levels of safety.

# %% [markdown]
# #### Loading packages

# %%
library(tidyverse)
library(testthat)
library(digest)
library(repr)
library(GGally)
library(ISLR)
library(infer)
options(repr.matrix.max.rows = 6)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘testthat’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     matches
#
#
# The following object is masked from ‘package:purrr’:
#
#     is_null
#
#
# The following objects are masked from ‘package:readr’:
#
#     edition_get, local_edition
#
#
# The following object is masked from ‘package:tidyr’:
#
#     matches
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %% [markdown]
# First we need to load all of the packages required to clean, wrangle, visualize etc., our data into this Jupyter notebook

# %% [markdown]
# #### Loading 2022 Crime Dataset of Vancouver

# %%
#Loading dataset from url
url = "https://raw.githubusercontent.com/abheetkansal/Dataset/main/crimedata_csv_AllNeighbourhoods_2022.csv"
crime_data <- read_csv(url)
head(crime_data)
# Out:
# Rows: 27883 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): TYPE, HUNDRED_BLOCK, NEIGHBOURHOOD
# dbl (7): YEAR, MONTH, DAY, HOUR, MINUTE, X, Y
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   TYPE               YEAR MONTH DAY HOUR MINUTE HUNDRED_BLOCK
# 1 Theft from Vehicle 2022 4     16   9   58     1XX W HASTINGS ST
# 2 Theft from Vehicle 2022 6     16  13    0     1XX W HASTINGS ST
# 3 Theft from Vehicle 2022 4     19  19    0     1XX W HASTINGS ST
# 4 Theft from Vehicle 2022 6      5  20   30     1XX W HASTINGS ST
# 5 Theft from Vehicle 2022 4     16  19   17     1XX W HASTINGS ST
# 6 Theft from Vehicle 2022 1      4   3   54     1XX W PENDER ST
#   NEIGHBOURHOOD             X        Y
# 1 Central Business District 492101.0 5458837
# 2 Central Business District 492107.4 5458835
# 3 Central Business District 492113.5 5458843
# 4 Central Business District 492182.6 5458822
# 5 Central Business District 492197.2 5458808
# 6 Central Business District 492073.2 5458730

# %% [markdown]
# Making a variable `url` which contains the link to the data set that we are using, and reading it into a variable `crime_data` which will be used throughout.

# %% [markdown]
# #### Cleaning dataset for first hypothesis test

# %%
#Cleaning dataset for the crime type in research question
crime_data_cleaned <- crime_data %>% 
    filter(TYPE == "Offence Against a Person" | TYPE == "Other Theft")%>%
    filter(!is.na(NEIGHBOURHOOD)) %>%
    filter(!is.na(TYPE))%>%
    select(TYPE,NEIGHBOURHOOD)

head(crime_data_cleaned)
# Out:
#   TYPE                     NEIGHBOURHOOD
# 1 Offence Against a Person Stanley Park
# 2 Offence Against a Person Stanley Park
# 3 Offence Against a Person West End
# 4 Offence Against a Person West End
# 5 Offence Against a Person West End
# 6 Offence Against a Person West End

# %% [markdown]
# For our first hypothesis test we decided to use the crime types `Offence Against a Person` and `Other Theft`. In this cell we select these two crime types and filter out all of the other crime types recorded in our chosen dataset, aswell as filtering out any missing values.

# %% [markdown]
# #### Filtering the dataset with the crime in neighbourhoods Central Business District and West End as per the hypothesis test

# %%
#Filtering the required neighbourhoods as per the research question 1
crime_data_cleaned2 <- crime_data_cleaned  %>%
    filter(NEIGHBOURHOOD == "Central Business District" | NEIGHBOURHOOD == "West End")
head(crime_data_cleaned2)
# Out:
#   TYPE                     NEIGHBOURHOOD
# 1 Offence Against a Person West End
# 2 Offence Against a Person West End
# 3 Offence Against a Person West End
# 4 Offence Against a Person West End
# 5 Offence Against a Person West End
# 6 Offence Against a Person West End

# %% [markdown]
# In our first hypothesis test we are only looking at our chosen crime types in the neighbourhoods of `Central Buisness District` and `West End`, so here filter out all neighbourhoods that are not those two.

# %% [markdown]
# #### Counting the crime type per `NEIGHBOURHOOD` in question for crime with the crime `TYPE`

# %%
crime_count<-crime_data_cleaned2 %>%
    group_by(NEIGHBOURHOOD) %>%
    count(TYPE)
crime_count
# Out:
#   NEIGHBOURHOOD             TYPE                     n
# 1 Central Business District Offence Against a Person 1148
# 2 Central Business District Other Theft              2665
# 3 West End                  Offence Against a Person  387
# 4 West End                  Other Theft               686

# %% [markdown]
# We create `crime_count` which holds the number of our amount of times our chosen crimes  happened and were recorded in our chosen neighbourhoods, which we will later graph.

# %% [markdown]
# #### Calculating difference in proportions

# %%
obs_diff_prop1 <- crime_data_cleaned2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    calculate(stat = "diff in props", order = c("Central Business District", "West End"))
obs_diff_prop1
# Out:
#   stat
# 1 -0.05959575

# %% [markdown]
# Recorded above is the difference in proportions of `Offence Against a Person` crimes in our chosen neighbourhoods

# %%
obs_diff_prop2 <- crime_data_cleaned2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Other Theft") %>%
    calculate(stat = "diff in props", order = c("Central Business District", "West End"))
obs_diff_prop2
# Out:
#   stat
# 1 0.05959575

# %% [markdown]
# Recorded above is the test statistic of `Other Theft` crimes in our chosen neighbourhoods

# %% [markdown]
# #### Plotting a bar graph for `crime_count`

# %%
crime_data_count_plot <- crime_count %>%
       ggplot(aes(x = TYPE, y = n)) + 
       geom_col() +
       ggtitle("Frequency") +
       xlab("Theft Type")+
       ylab("Frequency Plot for Crime Type")

crime_data_count_plot
# Out:
# plot without title

# %% [markdown]
# Visualizing the amount of times one of our chosen crimes was committed in our chosen neighbourhoods via a bar graph

# %% [markdown]
# #### Plotting a pair plot

# %%
crime_data_plot <- ggpairs(crime_data_cleaned2)

crime_data_plot
# Out:
# plot without title

# %% [markdown]
# Here we are creating and visualizing the pair plot of our cleaned data set.

# %% [markdown]
# #### Creating a null disribution

# %%
set.seed(20)
null_dist <- crime_data_cleaned2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    hypothesize(null = "independence") %>%
    generate(reps = 400, type = "permute") %>%
    calculate(stat = "diff in props", order = c("Central Business District", "West End"))
head(null_dist)
# Out:
#   replicate stat
# 1 1          0.001309837
# 2 2         -0.027351614
# 3 3         -0.015409343
# 4 4         -0.015409343
# 5 5          0.009669427
# 6 6         -0.014215116

# %% [markdown]
# Above is the null distribution of our cleaned data set `crime_data_cleaned2`.

# %% [markdown]
# #### Visualizing our null distribution

# %%
hypo_test_plot <- null_dist %>%
    visualize(bins = 20) +
    shade_p_value(obs_stat = obs_diff_prop1, direction = "left") + 
    xlab("Differnce in Proportions") +
    ggtitle("Null Distribution for Central Business District")
hypo_test_plot
# Out:
# plot without title

# %% [markdown]
# Here is the visualization of our null hypothesis which shows that our p-value is not inside of the distribution, suggesting that the p-value is very small and should be rejected.

# %% [markdown]
# #### Getting the p-value from our null distribution

# %%
p_value <- null_dist %>%
    get_p_value(obs_stat = obs_diff_prop1, direction = "left")
p_value
# Out:
# Warning message:
# “Please be cautious in reporting a p-value of 0. This result is an approximation based on the number of `reps` chosen in the `generate()` step. See `?get_p_value()` for more information.”
#   p_value
# 1 0

# %% [markdown]
# We now use the `infer` package to get the p-value. Since our p-value is ~0 which is less than α = 0.05, we will reject the null hypothesis.
#
# This p-value of 0 is really a delegate of a very low likelihood (not truly 0) of computing a more-outrageous value than the noticed one under the invalid speculation, or in rundown, that our noticed value is exceptionally outrageous under the null. We could possibly get a hardly higher p-value by switching up the quantity of reps or test sizes, however this wouldn't change the understanding a lot; the p-value would in any case be illustrative of an exceptionally low likelihood of securing a more outrageous value.

# %% [markdown]
# #### Creating a bootstrap distribution from our dataset

# %%
set.seed(20)
bootstrap_dist <- crime_data_cleaned2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    generate(reps = 400, type = "bootstrap") %>%
    calculate(stat = "diff in props", order = c("Central Business District", "West End"))
head(bootstrap_dist)
# Out:
#   replicate stat
# 1 1         -0.07999129
# 2 2         -0.06747456
# 3 3         -0.07967087
# 4 4         -0.05339089
# 5 5         -0.05320912
# 6 6         -0.06902432

# %% [markdown]
# We create a bootstrap distribution of our cleaned dataset so we can find a confidence interval and visualize it.

# %% [markdown]
# #### Getting the confidence interval from our bootstrap distribution

# %%
ci <- bootstrap_dist %>%
        summarise(lower_ci = quantile(stat, 0.025), upper_ci = quantile(stat, 0.975))
ci
# Out:
#   lower_ci    upper_ci
# 1 -0.09025807 -0.02443591

# %% [markdown]
# We calculate the 95% confidence interval which is between -0.09025807 and -0.02443591.

# %% [markdown]
# #### Visualizing the confidence interval of our bootstrap distribution

# %%
ci_plot <- bootstrap_dist %>%
    visualize() +
    shade_confidence_interval(endpoints = ci) +
    ggtitle("Bootstrap Distribution")+
    xlab("Difference In Proportion")
ci_plot
# Out:
# plot without title

# %% [markdown]
# What this visualization shows is that we are 95% confident that the true proportion difference is between `-0.09025807` and `-0.02443591`. With that, we are 95% confident that the proportion of crimes against persons among all other types of crime in West End is less than the proportion in Central Business District in Vancouver, accepting our alternative hypothesis.

# %% [markdown]
# #### Creating a second hypothesis test with different neighbourhoods

# %% [markdown]
# **Research Question 2:**</br>
# Let <i>p<sub>a</sub></i> be the proportion of offence against a person among all other types of crime in Kitsilano </br>
# Let <i>p<sub>b</sub></i> be the proportion of offence against a person among all other types of crime in Kerrisdale </br>
#
#
# <center><i>H<sub>θ</sub></i> : <i>p<sub>a</sub></i>=<i>p<sub>b</sub></i></center>
# The proportion of offence against persons among all other types of crime is the same in Kitsilano and Kerrisdale in Vancouver<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#
# <center><i>H<sub>1</sub></i> : <i>p<sub>a</sub></i>><i>p<sub>b</sub></i> </center>
# The proportion of offence against persons among all other types of crime in Kerrisdale is less than the proportion in Kitsilano in Vancouver

# %% [markdown]
# <b>METHODS:</b>  We’ll begin by using Hypothesis testing to assess the plausibility of the hypothesis, whether the data obtained from samples provides evidence against our claim that H. Through the infer workflow, which ensures tidy and clean data while using expressive grammar for the statistical inference, we will calculate the p-value. The p-value will be used to reject the null hypothesis H. Then through samples obtained through bootstrap resampling with replacement, which allows us to mimic sampling variation without the full population, we will calculate our point estimate of sample proportion and visualize the results with a confidence interval of 95% to conclude to stakeholders how confident we are with the results.
#
# We expect that the p-value to be greater than the significance level to accept our null hypothesis. This can prove our point that the Kitsilano and Kerrisdale being residential areas have similar crime rate for offence against a person.

# %%
#Cleaning dataset for the crime type in research question
crime_data_clean <- crime_data %>% 
    filter(TYPE == "Offence Against a Person" | TYPE == "Other Theft")%>%
    filter(!is.na(NEIGHBOURHOOD)) %>%
    filter(!is.na(TYPE))%>%
    select(TYPE,NEIGHBOURHOOD)

head(crime_data_clean)
# Out:
#   TYPE                     NEIGHBOURHOOD
# 1 Offence Against a Person Stanley Park
# 2 Offence Against a Person Stanley Park
# 3 Offence Against a Person West End
# 4 Offence Against a Person West End
# 5 Offence Against a Person West End
# 6 Offence Against a Person West End

# %% [markdown]
# We want to create a second hypothesis test to compare to the our first hypothesis test. Again we filter `crime_data` so the only crime types are `Offence Against a Person` and `Other Theft`, and all missing values are filtered out.

# %% [markdown]
# #### Filtering the dataset for new chosen `NEIGHBOURHOOD`

# %%
#Filtering dataset for the neighbouhood in research question 2
crime_data_clean2 <- crime_data_clean  %>%
    filter(NEIGHBOURHOOD == "Kitsilano" | NEIGHBOURHOOD == "Kerrisdale")
head(crime_data_clean2)
# Out:
#   TYPE                     NEIGHBOURHOOD
# 1 Offence Against a Person Kitsilano
# 2 Offence Against a Person Kitsilano
# 3 Offence Against a Person Kitsilano
# 4 Offence Against a Person Kitsilano
# 5 Offence Against a Person Kitsilano
# 6 Offence Against a Person Kitsilano

# %% [markdown]
# We create `crime_data_clean2` which contains `crime_data_clean`, but this time we will filter to choose `Kitsilano` and `Kerrisdale` for the neighbourhoods.

# %% [markdown]
# #### Counting the crime type per `NEIGHBOURHOOD` in question for crime with the crime `TYPE`

# %%
crime_count2 <- crime_data_clean2 %>%
    group_by(NEIGHBOURHOOD) %>%
    count(TYPE)
crime_count2
# Out:
#   NEIGHBOURHOOD TYPE                     n
# 1 Kerrisdale    Offence Against a Person  16
# 2 Kerrisdale    Other Theft               80
# 3 Kitsilano     Offence Against a Person  48
# 4 Kitsilano     Other Theft              288

# %% [markdown]
# Creating a variable `crime_count2` that has the amount of times our chosen crimes were committed and recorded in our two new chosen neighbourhoods.

# %% [markdown]
# #### Calculating difference in proportions

# %%
obs_diff_props1 <- crime_data_clean2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    calculate(stat = "diff in props", order = c("Kitsilano", "Kerrisdale"))
obs_diff_props1
# Out:
#   stat
# 1 -0.02380952

# %% [markdown]
# Calculating the test statistic of `Offence Against a Person` in Kitsilano and Kerrisdale.

# %%
obs_diff_props2 <- crime_data_clean2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Other Theft") %>%
    calculate(stat = "diff in props", order = c("Kitsilano", "Kerrisdale"))
obs_diff_props2
# Out:
#   stat
# 1 0.02380952

# %% [markdown]
# Calculating the test statistic of `Other Theft` in Kitsilano and Kerrisdale.

# %% [markdown]
# #### Plotting a bar graph of `crime_count2`

# %%
crime_data_count_plot2 <- crime_count2 %>%
       ggplot(aes(x = TYPE, y = n)) + 
       geom_col() +
       ggtitle("Frequency") +
       xlab("Theft Type")+
       ylab("Frequency Plot for Crime Type")

crime_data_count_plot2
# Out:
# plot without title

# %% [markdown]
# We create a bar graph of `crime_count2` which visually shows the amount of our chosen crimes commited in our new chosen neighbourhoods.

# %% [markdown]
# #### Plotting a pair plot

# %%
crime_data_plot2 <- ggpairs(crime_data_clean2)

crime_data_plot2
# Out:
# plot without title

# %% [markdown]
# Creating and visualizing a pair plot `crime_data_clean2`.

# %% [markdown]
# #### Creating a null distribution for our second hypothesis test

# %%
set.seed(20)
null_dist2 <- crime_data_clean2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    hypothesize(null = "independence") %>%
    generate(reps = 400, type = "permute") %>%
    calculate(stat = "diff in props", order = c("Kitsilano", "Kerrisdale"))
head(null_dist2)
# Out:
#   replicate stat
# 1 1         -0.01041667
# 2 2         -0.01041667
# 3 3          0.04315476
# 4 4          0.01636905
# 5 5         -0.06398810
# 6 6         -0.06398810

# %% [markdown]
# Now we create a null distribution of `crime_data_clean2` which will be used to find the p-value.

# %% [markdown]
# #### Visualizing the difference in proportions of `null_dist2`

# %%
hypo_test_plot2 <- null_dist2 %>%
    visualize(bins = 20) +
    shade_p_value(obs_stat = obs_diff_props1, direction = "left") + 
    xlab("Difference in Proportions") +
    ggtitle("Null Distribution for Kitsilano")
hypo_test_plot2
# Out:
# plot without title

# %% [markdown]
# Visualizing `null_dist2`, we see that our p-value is inside of our distribution, suggesting that the p-value is not very small and maybe we should accept.

# %% [markdown]
# #### Getting the p-value from `null_dist2`

# %%
p_value2 <- null_dist2 %>%
    get_p_value(obs_stat = obs_diff_props1, direction = "left")
p_value2
# Out:
#   p_value
# 1 0.3525

# %% [markdown]
# We get a p-value of 0.3525, concluding that the p-value > α (α = 0.05), meaning that we will accept our null hypothesis.

# %% [markdown]
# #### Creating a bootstrap distribution for our second hypothesis test

# %%
set.seed(20)
bootstrap_dist2 <- crime_data_clean2 %>%
    specify(formula = TYPE ~ NEIGHBOURHOOD, success = "Offence Against a Person") %>%
    generate(reps = 400, type = "bootstrap") %>%
    calculate(stat = "diff in props", order = c("Kitsilano", "Kerrisdale"))
head(bootstrap_dist2)
# Out:
#   replicate stat
# 1 1         -0.034446665
# 2 2         -0.020076726
# 3 3          0.008928571
# 4 4          0.006344616
# 5 5         -0.043606138
# 6 6          0.039886040

# %% [markdown]
# We now create a bootstrap distribution of `crime_data_clean2` to be used when getting a confidence interval.

# %% [markdown]
# #### Getting the confidence interval of `bootstrap_dist2`

# %%
ci2 <- bootstrap_dist2 %>%
        summarise(lower_ci = quantile(stat, 0.025), upper_ci = quantile(stat, 0.975))
ci2
# Out:
#   lower_ci    upper_ci
# 1 -0.09888061 0.05734264

# %% [markdown]
# We calculate the 95% confidence interval which is between -0.09888061 and 0.05734264.

# %% [markdown]
# #### Visualizing the confidence interval of `bootstrap_dist2`

# %%
ci_plot2 <- bootstrap_dist2 %>%
    visualize() +
    shade_confidence_interval(endpoints = ci2) +
    ggtitle("Bootstrap Distribution")+
    xlab("Difference in Proportion")
ci_plot2
# Out:
# plot without title

# %% [markdown]
# This visualization shows is that we are 95% confident that the true proportion difference is between `-0.09888061` and `0.05734264`. With that, we are 95% confident that the proportion of theft from vehicles among all other types of crime is the same in Kitsilano and Kerrisdale in Vancouver, accepting our null hypothesis.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **FINDINGS FOR RESEARCH QUESTION 1:**</br>
#
# With reference to our first hypothesis test, it was concluded that our p-value is ~0, and since our p-value is less than our signifiance level of α = 0.05, we will reject the null hypothesis:<center><i>H<sub>θ</sub></i> : <i>p<sub>1</sub></i>=<i>p<sub>2</sub></i></center>
# Since the p-value ~ 0, it suggest that it is highly unlikely for the null hypothesis will occur, where the p-value is defined as how frequent it is to observe the data from the experiment if null hypothesis is true.
#
# As a result we are 95% confident that the proportion of crimes against persons among all other types of crime in the Central Business District is higher than the rates in West End, accepting our alternative hypothesis.
#
# </br>
#
# **FINDINGS FOR RESEARCH QUESTION 2:**</br>
#
# With reference to our second hypothesis test, it was concluded that our p-value is 0.3525, and since our p-value is greater than our signifiance level of α = 0.05, we will accept the null hypothesis:<center><i>H<sub>θ</sub></i> : <i>p<sub>a</sub></i>=<i>p<sub>b</sub></i></center>
# Since the p-value = 0.3525, it suggest that it is highly likely that our null hypothesis is true, where the p-value is defined as how frequent it is to observe the data from the experiment if null hypothesis is true.
#
# As a result we are 95% confident that the proportion of crimes against persons among all other types of crime in Kitsilano is similar to the crime rates rates in Kerrisdale, accepting our null hypothesis.
#
# </br>
#
# **APPLICATION OF FINDINGS:**</br>
#
# From the findings, it is proven in our first analysis that the Central Business District has higher rates of crimes compared to West End, so more enforcement should be implemented in that area to control the crimes happening. As for our second analysis, Kitsilano and Kerrisdale, it was deduced that both neighbourhoods have about the same proportions of crimes. Despite the previous hypothesis in our introduction, that Kitsilano will have a higher crime rate due to increased commercialization. After comparing it to Kerrisdale, it can be suggested that commercialization may not impact the rate of crime to a large extent, since both proportions are the same. As a result, it implies that other factors would be the cause. Hence, the cause of crime can be a future topic of research and study, in order to control the rates of crimes, such as comparing the rates of crimes from other years, to find the pressing causation and correlation of crime, such as the pandemic, rise in rent, etc., which can be done through conducted surveys.
#
#
#
# </br>
#
# **REFERENCES:** <br>
#
# Areavibes, 2020. Kerrisdale, Vancouver, BC Crime. [assessed 2022 Nov 11].
# https://www.areavibes.com/vancouver-bc/kerrisdale/crime/
#
# Areavibes, 2020. Kitsilano, Vancouver, BC Crime. [assessed 2022 Nov 11].
# https://www.areavibes.com/vancouver-bc/kitsilano/crime/
#
# CBC News. 2022. New study shows higher incidence of violent crime in poor Vancouver neighborhoods,theft in wealthier ones. [assessed 2022 Oct 29].
# https://www.cbc.ca/news/canada/british-columbia/sfu-study-vancouver-crime-impacts-1.6323902#:~:text=Andresen%20says%20this%20can%20be,happened%20normally%2C%22%20he%20said.
#
# The Canadian Press. 2017. Soaring rents push homelessness to all-time high in vancouver’s DTES. [assessed 2022 Oct 29]. https://www.cbc.ca/news/canada/british-columbia/rent-increase-dtes-vancouver-homelessness-1.4034161.
#
# Numbeo. Crime in Vancouver, Canada. Numbeo. [assessed 2022 Oct 29]. https://www.numbeo.com/crime/in/Vancouver.
#
# Webster B R. How are the bad areas in Vancouver? [assessed 2022 Oct 29]. https://newcanadianlife.com/what-are-the-bad-areas-in-vancouver/.
